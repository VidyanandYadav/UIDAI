# %% [markdown]
# <a href="https://colab.research.google.com/github/VidyanandYadav/UIDAI/blob/main/Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('final1.csv')

# %%
df.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  2025-03-02      Meghalaya  East Khasi Hills   793121       11        61
# 1  2025-03-09      Karnataka   Bengaluru Urban   560043       14        33
# 2  2025-03-09  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  2025-03-09  Uttar Pradesh           Aligarh   202133       62        29
# 4  2025-03-09      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater
# 0              37
# 1              39
# 2              12
# 3              15
# 4              21

# %%
# import re

# df['district'] = (
#     df['district']
#     .str.lower()
#     .str.strip()
#     .str.replace(r'\s+', ' ', regex=True)   # extra spaces
#     .str.replace(r'[\*\(\)\.\-]', '', regex=True)  # *, (), ., -
# )

# %%
l2=[]
l1=[]
for i in (df['state']).unique():
        l2.append(i)
        l1.append(len(sorted(df[df['state']==i]['district'].unique())))

# %%
pd.DataFrame({'state':l2,'num_district':l1}).sort_values(by='state').
# Out:
#                                        state  num_district
# 33               Andaman and Nicobar Islands             5
# 14                            Andhra Pradesh            49
# 29                         Arunachal Pradesh            25
# 11                                     Assam            38
# 3                                      Bihar            48
# 24                                Chandigarh             2
# 16                              Chhattisgarh            40
# 28  Dadra and Nagar Haveli and Daman and Diu             5
# 8                                      Delhi            14
# 31                                       Goa             3
# 13                                   Gujarat            40
# 5                                    Haryana            26
# 30                          Himachal Pradesh            14
# 23                         Jammu and Kashmir            28
# 17                                 Jharkhand            35
# ...

# %%
df['district'].nunique()
# Out:
# 984

# %%
# sorted(df['district'])

# %%
sorted(df['state'].unique())
# Out:
# ['Andaman and Nicobar Islands',
#  'Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chandigarh',
#  'Chhattisgarh',
#  'Dadra and Nagar Haveli and Daman and Diu',
#  'Delhi',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu and Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Ladakh',
#  'Lakshadweep',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Puducherry',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal']

# %% [markdown]
# nagaland,goa,Puducherry

# %%
df[df['district']=='Jaintia Hills']
# Out:
#               date      state       district  pincode  age_0_5  age_5_17  \
# 360385  2025-10-13  Meghalaya  Jaintia Hills   793200        1         0
# 430923  2025-10-18  Meghalaya  Jaintia Hills   793150        1         0
# 480831  2025-10-25  Meghalaya  Jaintia Hills   793151        1         0
# 569864  2025-09-05  Meghalaya  Jaintia Hills   793150        1         0
#
#         age_18_greater
# 360385               0
# 430923               0
# 480831               0
# 569864               0

# %%
# sorted(df[df['district']=='West Jaintia Hills']['pincode'])

# %%
sorted(df[df['district']=='East Jaintia Hills']['pincode'])
# Out:
# [793109,
#  793109,
#  793109,
#  793109,
#  793150,
#  793151,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793160,
#  793200,
#  793200,
#  793200,
#  793200,
#  793200,
#  793200,
#  793200,
#  793200,
#  793200,
#  793200,
#  793200,
#  793200,
#  793200,
#  793200,
#  793200,
#  793200,
#  793200,
#  793200,
#  793200,
#  793200,
#  793200,
#  793200,
# ...

# %%
def all_distict_name(state):
   count=1
   for i in state:
       print(count,i,'\n')
       print(sorted(df[df['state']==i]['district'].unique()),'\n')
       count=count+1

# %%
all_distict_name(sorted(df['state'].unique()))
# Out:
# 1 Andaman and Nicobar Islands
#
# ['Andamans', 'Nicobar', 'Nicobars', 'North And Middle Andaman', 'South Andaman']
#
# 2 Andhra Pradesh
#
# ['Adilabad', 'Alluri Sitharama Raju', 'Anakapalli', 'Anantapur', 'Ananthapur', 'Ananthapuramu', 'Annamayya', 'Bapatla', 'Chittoor', 'Cuddapah', 'Dr. B. R. Ambedkar Konaseema', 'East Godavari', 'Eluru', 'Guntur', 'Hyderabad', 'K.V.Rangareddy', 'K.v. Rangareddy', 'Kakinada', 'Karim Nagar', 'Karimnagar', 'Khammam', 'Krishna', 'Kurnool', 'Mahabub Nagar', 'Mahabubnagar', 'Mahbubnagar', 'Medak', 'N. T. R', 'Nalgonda', 'Nandyal', 'Nellore', 'Nizamabad', 'Palnadu', 'Parvathipuram Manyam', 'Prakasam', 'Rangareddi', 'Spsr Nellore', 'Sri Potti Sriramulu Nellore', 'Sri Sathya Sai', 'Srikakulam', 'Tirupati', 'Visakhapatanam', 'Visakhapatnam', 'Vizianagaram', 'Warangal', 'West Godavari', 'Y. S. R', 'chittoor', 'rangareddi']
#
# 3 Arunachal Pradesh
#
# ...

# %%
df[df['state']=='Uttar Pradesh']['district'].nunique()
# Out:
# 89

# %%
df['district'].nunique()
# Out:
# 984

# %%
#sorted(df['district'].unique())

# %%
len(sorted(df[df['state']=='Kerala']['district'].unique()))
# Out:
# 15

# %%
# sorted(df[df['state']=='Uttar Pradesh']['district'].unique())

# %%
# import re

# def normalize(x):
#     if pd.isna(x):
#         return x
#     x = x.lower().strip()
#     x = re.sub(r'[^a-z\s]', '', x)
#     x = re.sub(r'\s+', ' ', x)
#     return x



# def clean_district(x):
#     key = normalize(x)
#     return district_map.get(key, x.strip().title())

# %%
# df['district_clean'] = df['district'].apply(clean_district)

# %%
dist_mapped={
    # 1 west Bengal
    '24 Paraganas North': 'North 24 Parganas',
    '24 Paraganas South': 'South 24 Parganas',
    'Barddhaman': 'Bardhaman',
    'Burdwan': 'Bardhaman',
    'Cooch Behar': 'Coochbehar',
    'Dakshin Dinajpur': 'South Dinajpur',
    'Dinajpur Dakshin': 'South Dinajpur',
    'Dinajpur Uttar': 'North Dinajpur',
    'Darjiling': 'Darjeeling',
    'East Midnapur': 'East Midnapore',
    'HOOGHLY': 'Hooghly',
    'HOWRAH': 'Howrah',
    'Haora': 'Hooghly',
    'Hawrah': 'Howrah',
    'Hooghiy': 'Hooghly',
    'Hugli': 'Hooghly',
    'KOLKATA': 'Kolkata',
    'Koch Bihar': 'Coochbehar',
    'MALDA': 'Malda',
    'Maldah': 'Malda',
    'Medinipur': 'Medinipur West',
    'NADIA': 'Nadia',
    'North Twenty Four Parganas': 'North 24 Parganas',
    'Puruliya': 'Purulia',
    'South 24 Pargana': 'South 24 Parganas',
    'South 24 parganas': 'South 24 Parganas',
    'South Twenty Four Parganas': 'South 24 Parganas',
    'West Midnapore': 'West Medinipur',
    'hooghly': 'Hooghly',
    'nadia': 'Nadia',

    #2 uttarakhand
    'Hardwar': 'Haridwar',
    'Garhwal': 'Pauri Garhwal',

    #3 uttar pradesh
    'Allahabad': 'Prayagraj',
    'Bagpat': 'Baghpat',
    'Bulandshahar': 'Bulandshahr',
    'Jyotiba Phule Nagar': 'Amroha',
    'Kushi Nagar': 'Kushinagar',
    'Kushinagar *': 'Kushinagar',
    'Mahrajganj': 'Maharajganj',
    'Rae Bareli': 'Raebareli',
    'Shrawasti': 'Shravasti',
    'Siddharthnagar': 'Siddharth Nagar',
    'Sant Ravidas Nagar Bhadohi': 'Bhadohi',
    'Sant Ravidas Nagar': 'Bhadohi',
    'Faizabad': 'Ayodhya',
    'Bara Banki': 'Barabanki',
    'Bhadohi': 'Bhadohi',

    # 4 tripura
    'Dhalai  *': 'Dhalai',
    'North Tripura': 'North Tripura',
    'South Tripura': 'South Tripura',
    'West Tripura': 'West Tripura',
    'Gomati': 'Gomati',
    'Khowai': 'Khowai',
    'Sepahijala': 'Sepahijala',
    'Unakoti': 'Unakoti',

    # 5 telangana
    "Jagitial": "Jagtial",
    "Jangaon": "Jangaon",
    "Jangoan": "Jangaon",
    "K.v. Rangareddy": "Ranga Reddy",
    "Rangareddy": "Ranga Reddy",
    "Medchal Malkajgiri": "Medchal–Malkajgiri",
    "Medchal-malkajgiri": "Medchal–Malkajgiri",
    "Medchal?malkajgiri": "Medchal–Malkajgiri",
    "Medchal−malkajgiri": "Medchal–Malkajgiri",
    "Warangal (urban)": "Warangal Urban",
    "Warangal Rural": "Warangal Rural",
    "Warangal Urban": "Warangal Urban",
    "Yadadri.": "Yadadri Bhuvanagiri",

    # 6 tamil naidu
    "Kanchipuram": "Kancheepuram",
    "Kanniyakumari": "Kanyakumari",
    "Namakkal   *": "Namakkal",
    "Tirupattur": "Tirupathur",
    "Tiruvallur": "Thiruvallur",
    "Tiruvarur": "Thiruvarur",
    "Tuticorin": "Thoothukkudi",
    "Viluppuram": "Villupuram",

    # 7 sikkim
    "East": "East Sikkim",
    "Mangan": "North Sikkim",
    "Namchi": "South Sikkim",
    "North": "North Sikkim",
    "South": "South Sikkim",
    "West": "West Sikkim",

    # 8 Odisha
        "ANGUL": "Angul",
    "ANUGUL": "Angul",
    "Anugal": "Angul",
    "Anugul": "Angul",
    "Balangir": "Balangir",
    "Baleshwar": "Balasore",
    "Baleswar": "Balasore",
    "Bargarh": "Bargarh",
    "Baudh": "Boudh",
    "Bhadrak": "Bhadrak",
    "Boudh": "Boudh",
    "Cuttack": "Cuttack",
    "Debagarh": "Deogarh",
    "Dhenkanal": "Dhenkanal",
    "Gajapati": "Gajapati",
    "Ganjam": "Ganjam",
    "JAJPUR": "Jajpur",
    "Jagatsinghapur": "Jagatsinghpur",
    "Jagatsinghpur": "Jagatsinghpur",
    "Jajapur": "Jajpur",
    "Jajpur": "Jajpur",
    "Jharsuguda": "Jharsuguda",
    "Kalahandi": "Kalahandi",
    "Kandhamal": "Kandhamal",
    "Kendrapara": "Kendrapara",
    "Kendrapara *": "Kendrapara",
    "Kendujhar": "Keonjhar",
    "Khorda": "Khordha",
    "Khordha": "Khordha",
    "Koraput": "Koraput",
    "Malkangiri": "Malkangiri",
    "Mayurbhanj": "Mayurbhanj",
    "NUAPADA": "Nuapada",
    "Nabarangapur": "Nabarangapur",
    "Nabarangpur": "Nabarangapur",
    "Nayagarh": "Nayagarh",
    "Nuapada": "Nuapada",
    "Puri": "Puri",
    "Rayagada": "Rayagada",
    "Sambalpur": "Sambalpur",
    "Sonapur": "Sonapur",
    "Subarnapur": "Subarnapur",
    "Sundargarh": "Sundargarh",
    "Sundergarh": "Sundargarh",
    "jajpur": "Jajpur",


    # 9 Rajasthan
    "Balotra": "Barmer",
    "Banswara": "Banswara",
    "Chittaurgarh": "Chittorgarh",
    "Deeg": "Deeg",
    "Deeg\xa0": "Deeg",
    "Dhaulpur": "Dholpur",
    "Dholpur": "Dholpur",
    "Didwana-Kuchaman": "Didwana",
    "Ganganagar": "Sri Ganganagar",
    "Jhunjhunu": "Jhunjhunun",  # keep official spelling as "Jhunjhunu"
    "Jalore": "Jalor",
    "Salumbar": "Salumber",

    # 10 punjab
    "Firozpur": "Firozpur",
    "Ferozepur": "Firozpur",
    "Malerkotla": "Malerkotla",
    "Muktsar": "Sri Muktsar Sahib",
    "S.A.S Nagar": "Sahibzada Ajit Singh Nagar",
    "S.A.S Nagar(Mohali)": "Sahibzada Ajit Singh Nagar",
    "SAS Nagar (Mohali)": "Sahibzada Ajit Singh Nagar",
    "Shaheed Bhagat Singh Nagar": "Shaheed Bhagat Singh Nagar",
    "Sri Muktsar Sahib": "Sri Muktsar Sahib",

    # 11 ponducheery
    "Pondicherry": "Puducherry",
    "Karaikal": "Karaikal",
    "Yanam": "Yanam",
    "Puducherry": "Puducherry",

    #12 nagaland -. all cleaned

    # 13 mizzoram
    "Mammit": "Mamit",

    # 14 maharastra
    "Ahilyanagar": "Ahmadnagar",
    "Ahmed Nagar": "Ahmadnagar",
    "Ahmednagar": "Ahmadnagar",
    "Bid": "Beed",
    "Buldana": "Buldhana",
    "Chatrapati Sambhaji Nagar": "Aurangabad",
    "Chhatrapati Sambhajinagar": "Aurangabad",
    "Dharashiv": "Osmanabad",
    "Gondiya": "Gondia",
    "Gondiya *": "Gondia",
    "Hingoli *": "Hingoli",
    "Mumbai City": "Mumbai",
    "Mumbai( Sub Urban )": "Mumbai Suburban",
    "Nandurbar *": "Nandurbar",
    "Raigarh": "Raigad",
    "Raigarh(MH)": "Raigad",
    "Washim *": "Washim",

    # 15 madhya pradesh
    "Ashok Nagar": "Ashoknagar",
    "Harda *": "Harda",
    "East Nimar": "Khandwa",
    "West Nimar": "Khargone",
    "Narsimhapur": "Narsinghpur",
    "Hoshangabad": "Narmadapuram",
    # "Maihar": None,        # Tehsil, not a district
    # "Mauganj": None         # Tehsil, not a district

    # 16 karnataka
    "Bagalkot *": "Bagalkot",
    "Ballari": "Ballari",
    "Bellary": "Ballari",
    "Bangalore": "Bengaluru",
    "Bengaluru": "Bengaluru",
    "Bangalore Rural": "Bengaluru Rural",
    "Bijapur": "Vijayapura",
    "Bijapur(KAR)": "Vijayapura",
    "Chamarajanagar *": "Chamarajanagar",
    "Chamrajanagar": "Chamarajanagar",
    "Chamrajnagar": "Chamarajanagar",
    "Chickmagalur": "Chikkamagaluru",
    "Chikmagalur": "Chikkamagaluru",
    "Chikkamagaluru": "Chikkamagaluru",
    "Davanagere": "Davangere",
    "Hasan": "Hassan",
    "Haveri *": "Haveri",
    "Gulbarga": "Kalaburagi",
    "Mysore": "Mysuru",
    "Ramanagar": "Ramanagara",
    "Tumkur": "Tumakuru",
    "Udupi *": "Udupi",
    "yadgir": "Yadgir",
    "Shivamogga": "Shimoga",

    #17 jharkhand
    "Bokaro *": "Bokaro",
    "East Singhbum": "East Singhbhum",
    "Garhwa *": "Garhwa",
    "Hazaribag": "Hazaribagh",
    "Kodarma": "Koderma",
    "Pakaur": "Pakur",
    "Palamau": "Palamu",
    "Sahebganj": "Sahibganj",
    "Seraikela-kharsawan": "Seraikela-Kharsawan",

    #18 jammu & kashmir
    "Badgam": "Budgam",
    "Bandipur": "Bandipore",
    "Punch": "Poonch",
    "punch": "Poonch",
    "Rajauri": "Rajouri",
    "Shupiyan": "Shopian",
    "Leh (ladakh)": "Leh",

    # 19 himachal pradesh
    "Lahul & Spiti": "Lahaul and Spiti",
    "Lahul and Spiti": "Lahaul and Spiti",
    "Lahaul and Spiti": "Lahaul and Spiti",
    "Bilaspur": "Bilaspur",
    "Chamba": "Chamba",
    "Hamirpur": "Hamirpur",
    "Kangra": "Kangra",
    "Kinnaur": "Kinnaur",
    "Kullu": "Kullu",
    "Mandi": "Mandi",
    "Shimla": "Shimla",
    "Sirmaur": "Sirmaur",
    "Solan": "Solan",
    "Una": "Una",

    # 20 harayana
    "Jhajjar *": "Jhajjar",
    "Gurgaon": "Gurugram",
    "Yamuna Nagar": "Yamunanagar",


    # 21 gurarat
     "Ahmadabad": "Ahmedabad",
    "Banas Kantha": "Banaskantha",
    "Sabar Kantha": "Sabarkantha",
    "Surendra Nagar": "Surendranagar",
    "Panch Mahals": "Panchmahals",
    "The Dangs": "Dang",
    "Chhotaudepur": "Chhota Udepur",
    "Mahesana": "Mehsana",
    "Kachchh": "Kutch",
    "Arvalli": "Aravalli",
    "Mahisagar": "Mahisagar",
    "Dohad": "Dahod",

    # 22 Delhi
    "North East": "North East Delhi",
    "North East   *": "North East Delhi",
    "Najafgarh": "South West Delhi",
    "New Delhi": "Central Delhi",
    "Shahdara": "East Delhi",
    "Central Delhi": "Central Delhi",
    "East Delhi": "East Delhi",
    "North Delhi": "North Delhi",
    "North West Delhi": "North West Delhi",
    "South Delhi": "South Delhi",
    "South East Delhi": "South East Delhi",
    "South West Delhi": "South",

    # 23 Dadra and Nagar Haveli and Daman and Diu
    "Dadra & Nagar Haveli": "Dadra and Nagar Haveli",
    "Dadra And Nagar Haveli": "Dadra and Nagar Haveli",
    "Dadra and Nagar Haveli": "Dadra and Nagar Haveli",
    "Daman": "Daman",
    "Diu": "Diu",

    # 24 chhatisgarh
    "Gaurela-pendra-marwahi": "Gaurela Pendra Marwahi",
    "Janjgir - Champa": "Janjgir Champa",
    "Janjgir-champa": "Janjgir Champa",
    "Dakshin Bastar Dantewada": "Dantewada",
    "Manendragarh–Chirmiri–Bharatpur": "Manendragarh",
    "Mohalla-Manpur-Ambagarh Chowki": "Mohla-Manpur-Ambagarh Chouki",
    "Kabeerdham": "Kabirdham",
    "Kawardha": "Kabirdham",
    "Uttar Bastar Kanker": "Kanker",
    "Khairagarh Chhuikhadan Gandai": "Khairagarh-Chhuikhadan-Gandai",

    # 25 bihar
    "Aurangabad(BH)": "Aurangabad",
    "Aurangabad(bh)": "Aurangabad",
    "Bhabua": "Kaimur",
    "Kaimur (Bhabua)": "Kaimur",
    "Monghyr": "Munger",
    "Pashchim Champaran": "West Champaran",
    "Purba Champaran": "East Champaran",
    "Purbi Champaran": "East Champaran",
    "Purnea": "Purnia",
    "Samstipur": "Samastipur",
    "Sheikpura": "Sheikhpura",

    #26 assam
    "Sibsagar": "Sivasagar",
    "North Cachar Hills": "Dima Hasao",
    "West Karbi Anglong": "Karbi Anglong",
    "Marigaon": "Morigaon",
    "Tamulpur District": "Tamulpur",
    "Kamrup": "Kamrup Rural",
    "Kamrup Metro": "Kamrup Metropolitan",
    # "Sribhumi": None  # remove non-district

    # 27 Arunachal pradesh
    "Dibang Valley": "Lower Dibang Valley",
    "Leparada": "Lower Siang",
    "Shi-yomi": "Shi Yomi",
    "Kra-Daadi": "Kra Daadi",
    "Kra Daadi": "Kra Daadi",

    # 28 andra predesh
     "Anantapur": "Anantapuramu",
    "Ananthapur": "Anantapuramu",
    "chittoor": "Chittoor",
    "Cuddapah": "Kadapa",
    # "Hyderabad": None,  # remove, belongs to Telangana
    "K.V.Rangareddy": "Ranga Reddy",
    "K.v. Rangareddy": "Ranga Reddy",
    "Karim Nagar": "Karimnagar",
    "Mahabub Nagar": "Mahabubnagar",
    "Mahbubnagar": "Mahabubnagar",
    "N. T. R": "NTR",
    "Spsr Nellore": "Sri Potti Sriramulu Nellore",
    "Visakhapatanam": "Visakhapatnam",
    "rangareddi": "Ranga Reddy",
    "Y. S. R": "Y. S. R.",


    # 29 andaman & nicobar
    "Andamans": "South Andaman",
    "Nicobar": "Nicobar",
    "Nicobars": "Nicobar",
    "South Andaman": "South Andaman",
    "North And Middle Andaman": "North and Middle Andaman",

    # 30 manipur
    # 31 goa

    # 32 meghalaya
    # "Jaintia Hills": ["East Jaintia Hills", "West Jaintia Hills"], doubt
    "Eastern West Khasi Hills": "West Khasi Hills",
    # "Kamrup": None,  # remove
    "East Garo Hills": "East Garo Hills",
    "East Jaintia Hills": "East Jaintia Hills",
    "West Jaintia Hills": "West Jaintia Hills",
    "East Khasi Hills": "East Khasi Hills",
    "West Khasi Hills": "West Khasi Hills",
    "North Garo Hills": "North Garo Hills",
    "South Garo Hills": "South Garo Hills",
    "South West Garo Hills": "South West Garo Hills",
    "Ri Bhoi": "Ri Bhoi",
    "South West Khasi Hills": "South West Khasi Hills"

    # 33 ladhak
    # 34 lakhsdeep
    # 35 kerala
    # chandigarh
}

# %%
len(dist_mapped)
# Out:
# 324

# %%
# def clean_district(x):
#     key = normalize(x)
#     return district_map.get(key, x.strip().title())

# %%
l=sorted(df['district'])

# %%
df1=pd.DataFrame({'unclean_dist':l})

# %%
df1
# Out:
#                unclean_dist
# 0        24 Paraganas North
# 1        24 Paraganas North
# 2        24 Paraganas North
# 3        24 Paraganas North
# 4        24 Paraganas North
# ...                     ...
# 1006002              yadgir
# 1006003              yadgir
# 1006004              yadgir
# 1006005              yadgir
# 1006006              yadgir
#
# [1006007 rows x 1 columns]

# %%
df1['District_Clean'] = df1['unclean_dist'].replace(dist_mapped)

# %%
df1
# Out:
#                unclean_dist     District_Clean
# 0        24 Paraganas North  North 24 Parganas
# 1        24 Paraganas North  North 24 Parganas
# 2        24 Paraganas North  North 24 Parganas
# 3        24 Paraganas North  North 24 Parganas
# 4        24 Paraganas North  North 24 Parganas
# ...                     ...                ...
# 1006002              yadgir             Yadgir
# 1006003              yadgir             Yadgir
# 1006004              yadgir             Yadgir
# 1006005              yadgir             Yadgir
# 1006006              yadgir             Yadgir
#
# [1006007 rows x 2 columns]

# %%
df1['District_Clean'].nunique()
# Out:
# 779

# %%
df1['unclean_dist'].nunique()
# Out:
# 984

# %%
sorted(df1['District_Clean'].unique())
# Out:
# ['Adilabad',
#  'Agar Malwa',
#  'Agra',
#  'Ahmadnagar',
#  'Ahmedabad',
#  'Aizawl',
#  'Ajmer',
#  'Akola',
#  'Alappuzha',
#  'Aligarh',
#  'Alipurduar',
#  'Alirajpur',
#  'Alluri Sitharama Raju',
#  'Almora',
#  'Alwar',
#  'Ambala',
#  'Ambedkar Nagar',
#  'Amethi',
#  'Amravati',
#  'Amreli',
#  'Amritsar',
#  'Amroha',
#  'Anakapalli',
#  'Anand',
#  'Anantapuramu',
#  'Ananthapuramu',
#  'Anantnag',
#  'Angul',
#  'Anjaw',
#  'Annamayya',
#  'Anuppur',
#  'Araria',
#  'Aravalli',
#  'Ariyalur',
#  'Arwal',
#  'Ashoknagar',
#  'Auraiya',
#  'Aurangabad',
#  'Ayodhya',
#  'Azamgarh',
#  'Bagalkot',
#  'Bageshwar',
#  'Baghpat',
#  'Bahraich',
#  'Bajali',
#  'Baksa',
#  'Balaghat',
#  'Balangir',
#  'Balasore',
#  'Ballari',
#  'Ballia',
#  'Balod',
#  'Baloda Bazar',
#  'Balrampur',
#  'Banaskantha',
#  'Banda',
#  'Bandipore',
#  'Banka',
#  'Bankura',
#  'Banswara',
#  'Bapatla',
#  'Barabanki',
#  'Baramula',
#  'Baran',
#  'Bardez',
#  'Bardhaman',
#  'Bareilly',
# ...

# %%
df.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  2025-03-02      Meghalaya  East Khasi Hills   793121       11        61
# 1  2025-03-09      Karnataka   Bengaluru Urban   560043       14        33
# 2  2025-03-09  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  2025-03-09  Uttar Pradesh           Aligarh   202133       62        29
# 4  2025-03-09      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater
# 0              37
# 1              39
# 2              12
# 3              15
# 4              21

# %%
df['district'] = df['district'].replace(dist_mapped)

# %%
df['district'].nunique()
# Out:
# 779

# %%
l2=[]
l1=[]
for i in (df['state']).unique():
        l2.append(i)
        l1.append(len(sorted(df[df['state']==i]['district'].unique())))

# %%
pd.DataFrame({'state':l2,'num_district':l1}).sort_values(by='state')
# Out:
#                                        state  num_district
# 33               Andaman and Nicobar Islands             3
# 14                            Andhra Pradesh            40
# 29                         Arunachal Pradesh            23
# 11                                     Assam            35
# 3                                      Bihar            38
# 24                                Chandigarh             2
# 16                              Chhattisgarh            34
# 28  Dadra and Nagar Haveli and Daman and Diu             3
# 8                                      Delhi            10
# 31                                       Goa             3
# 13                                   Gujarat            33
# 5                                    Haryana            23
# 30                          Himachal Pradesh            12
# 23                         Jammu and Kashmir            22
# 17                                 Jharkhand            26
# ...

# %%
df.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  2025-03-02      Meghalaya  East Khasi Hills   793121       11        61
# 1  2025-03-09      Karnataka   Bengaluru Urban   560043       14        33
# 2  2025-03-09  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  2025-03-09  Uttar Pradesh           Aligarh   202133       62        29
# 4  2025-03-09      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater
# 0              37
# 1              39
# 2              12
# 3              15
# 4              21

# %%
df.to_csv("final2.csv")
